# %%
from kafka import KafkaConsumer, KafkaProducer
import pandas as pd
import json
import joblib

# Configuração do Kafka
bootstrap_servers = ['localhost:29092']
topicName = 'source.public.transacoes'  # Tópico de entrada
topic_elasticsearch = 'transacao_elastic'  # Tópico Kafka que envia para o Elasticsearch

# Inicializar o consumidor Kafka
consumer = KafkaConsumer(topicName, auto_offset_reset='earliest', 
                         bootstrap_servers=bootstrap_servers)

# Inicializar o produtor Kafka para enviar dados ao tópico Elasticsearch
producer = KafkaProducer(bootstrap_servers=bootstrap_servers,
                          value_serializer=lambda v: json.dumps(v).encode('utf-8'))

# Carregar modelo treinado
modelo = joblib.load(r"C:\Users\Matheus\Desktop\Estudo\Kafka\Transação_Credito\Previsao\models\fraud_detection.pkl")

print("🚀 Aguardando transações...")

for msg in consumer:
    try:
        # Ler mensagem do Kafka
        data = json.loads(msg.value.decode('utf-8'))  # Decodificar bytes para string e carregar como JSON
        print(f"📥 Transação recebida: {data}")

        # Transformar em DataFrame para passar ao modelo
        df_transacao = pd.DataFrame([data])

        # Selecionar apenas as colunas que o modelo precisa
        features = ['distance_from_home', 'distance_from_last_transaction', 
                    'ratio_to_median_purchase_price', 'repeat_retailer', 
                    'used_chip', 'used_pin_number', 'online_order']

        # Verificar se as colunas estão presentes no DataFrame
        if all(col in df_transacao.columns for col in features):
            # Fazer a previsão
            predicao = modelo.predict(df_transacao[features])[0]

            # Adicionar o resultado da previsão ao dicionário de dados
            data['resultado_previsao'] = 'fraude' if predicao == 1 else 'aprovada'

            # Enviar os dados com a previsão para o tópico do Elasticsearch
            producer.send(topic_elasticsearch, value=data)
            print(f"📤 Transação enviada para o Elasticsearch: {data}")
        else:
            print("❌ Colunas ausentes no DataFrame. Verifique a mensagem do Kafka.")
    except Exception as e:
        print(f"❌ Erro ao processar mensagem: {e}")
# Out:
# 🚀 Aguardando transações...
# 📥 Transação recebida: {'distance_from_home': 57.87785658389723, 'distance_from_last_transaction': 0.3111400080477545, 'ratio_to_median_purchase_price': 1.9459399775518595, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 57.87785658389723, 'distance_from_last_transaction': 0.3111400080477545, 'ratio_to_median_purchase_price': 1.9459399775518595, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 10.829942699255543, 'distance_from_last_transaction': 0.1755915022816658, 'ratio_to_median_purchase_price': 1.294218810619857, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 10.829942699255543, 'distance_from_last_transaction': 0.1755915022816658, 'ratio_to_median_purchase_price': 1.294218810619857, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 5.091079490616996, 'distance_from_last_transaction': 0.8051525945853258, 'ratio_to_median_purchase_price': 0.4277145611942758, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.091079490616996, 'distance_from_last_transaction': 0.8051525945853258, 'ratio_to_median_purchase_price': 0.4277145611942758, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 44.19093600261837, 'distance_from_last_transaction': 0.5664862680583477, 'ratio_to_median_purchase_price': 2.2227672978404707, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 44.19093600261837, 'distance_from_last_transaction': 0.5664862680583477, 'ratio_to_median_purchase_price': 2.2227672978404707, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 57.87785658389723, 'distance_from_last_transaction': 0.3111400080477545, 'ratio_to_median_purchase_price': 1.9459399775518595, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 57.87785658389723, 'distance_from_last_transaction': 0.3111400080477545, 'ratio_to_median_purchase_price': 1.9459399775518595, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 10.829942699255543, 'distance_from_last_transaction': 0.1755915022816658, 'ratio_to_median_purchase_price': 1.294218810619857, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 10.829942699255543, 'distance_from_last_transaction': 0.1755915022816658, 'ratio_to_median_purchase_price': 1.294218810619857, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 5.091079490616996, 'distance_from_last_transaction': 0.8051525945853258, 'ratio_to_median_purchase_price': 0.4277145611942758, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.091079490616996, 'distance_from_last_transaction': 0.8051525945853258, 'ratio_to_median_purchase_price': 0.4277145611942758, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 44.19093600261837, 'distance_from_last_transaction': 0.5664862680583477, 'ratio_to_median_purchase_price': 2.2227672978404707, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 44.19093600261837, 'distance_from_last_transaction': 0.5664862680583477, 'ratio_to_median_purchase_price': 2.2227672978404707, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 13.0584705141559, 'distance_from_last_transaction': 0.2560840637316123, 'ratio_to_median_purchase_price': 1.0012542942736853, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 13.0584705141559, 'distance_from_last_transaction': 0.2560840637316123, 'ratio_to_median_purchase_price': 1.0012542942736853, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 3.922211960165817, 'distance_from_last_transaction': 4.822091480482492, 'ratio_to_median_purchase_price': 0.7037704483696168, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 3.922211960165817, 'distance_from_last_transaction': 4.822091480482492, 'ratio_to_median_purchase_price': 0.7037704483696168, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 11.67231034681138, 'distance_from_last_transaction': 0.2239037396344751, 'ratio_to_median_purchase_price': 7.443476095886652, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 11.67231034681138, 'distance_from_last_transaction': 0.2239037396344751, 'ratio_to_median_purchase_price': 7.443476095886652, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 13.445376718775696, 'distance_from_last_transaction': 0.5828560278095959, 'ratio_to_median_purchase_price': 4.868268160285668, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 13.445376718775696, 'distance_from_last_transaction': 0.5828560278095959, 'ratio_to_median_purchase_price': 4.868268160285668, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 25.51736574091718, 'distance_from_last_transaction': 0.018884654389403, 'ratio_to_median_purchase_price': 10.559113440766549, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 25.51736574091718, 'distance_from_last_transaction': 0.018884654389403, 'ratio_to_median_purchase_price': 10.559113440766549, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 1.5369209800836467, 'distance_from_last_transaction': 8.049938810132392, 'ratio_to_median_purchase_price': 13.334843665405913, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 1.5369209800836467, 'distance_from_last_transaction': 8.049938810132392, 'ratio_to_median_purchase_price': 13.334843665405913, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 67.59186117206991, 'distance_from_last_transaction': 1.6129955621122185, 'ratio_to_median_purchase_price': 0.207043004519453, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 67.59186117206991, 'distance_from_last_transaction': 1.6129955621122185, 'ratio_to_median_purchase_price': 0.207043004519453, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 335.1893199927121, 'distance_from_last_transaction': 1.1141676662234867, 'ratio_to_median_purchase_price': 0.0982428061882022, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 335.1893199927121, 'distance_from_last_transaction': 1.1141676662234867, 'ratio_to_median_purchase_price': 0.0982428061882022, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 2.131955665990563, 'distance_from_last_transaction': 56.3724005365082, 'ratio_to_median_purchase_price': 6.358667321630612, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.131955665990563, 'distance_from_last_transaction': 56.3724005365082, 'ratio_to_median_purchase_price': 6.358667321630612, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 111.28520610936934, 'distance_from_last_transaction': 0.3790316875990881, 'ratio_to_median_purchase_price': 1.8584721733251552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 111.28520610936934, 'distance_from_last_transaction': 0.3790316875990881, 'ratio_to_median_purchase_price': 1.8584721733251552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 24.33748770584292, 'distance_from_last_transaction': 1.3986182664381062, 'ratio_to_median_purchase_price': 6.230792396550816, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 24.33748770584292, 'distance_from_last_transaction': 1.3986182664381062, 'ratio_to_median_purchase_price': 6.230792396550816, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 17.043384432449976, 'distance_from_last_transaction': 0.3282733826369984, 'ratio_to_median_purchase_price': 0.3472038763553988, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 17.043384432449976, 'distance_from_last_transaction': 0.3282733826369984, 'ratio_to_median_purchase_price': 0.3472038763553988, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 10.594372771059918, 'distance_from_last_transaction': 0.300184221962306, 'ratio_to_median_purchase_price': 4.766703962782415, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 10.594372771059918, 'distance_from_last_transaction': 0.300184221962306, 'ratio_to_median_purchase_price': 4.766703962782415, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 15.23536145541202, 'distance_from_last_transaction': 0.300208724552423, 'ratio_to_median_purchase_price': 0.4642727680509552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 15.23536145541202, 'distance_from_last_transaction': 0.300208724552423, 'ratio_to_median_purchase_price': 0.4642727680509552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 10.664473716016785, 'distance_from_last_transaction': 1.565769086201661, 'ratio_to_median_purchase_price': 4.886520843107555, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 10.664473716016785, 'distance_from_last_transaction': 1.565769086201661, 'ratio_to_median_purchase_price': 4.886520843107555, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 3.2160447557707816, 'distance_from_last_transaction': 17.144735923073647, 'ratio_to_median_purchase_price': 1.788833243120637, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 3.2160447557707816, 'distance_from_last_transaction': 17.144735923073647, 'ratio_to_median_purchase_price': 1.788833243120637, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 85.83725334092371, 'distance_from_last_transaction': 1.0351178763066122, 'ratio_to_median_purchase_price': 0.8682956142370105, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 85.83725334092371, 'distance_from_last_transaction': 1.0351178763066122, 'ratio_to_median_purchase_price': 0.8682956142370105, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 1.1158806875176952, 'distance_from_last_transaction': 0.1702369279899755, 'ratio_to_median_purchase_price': 4.127313378541158, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 1.1158806875176952, 'distance_from_last_transaction': 0.1702369279899755, 'ratio_to_median_purchase_price': 4.127313378541158, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 12.750894983835098, 'distance_from_last_transaction': 0.8576140872936847, 'ratio_to_median_purchase_price': 17.70614527869426, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 12.750894983835098, 'distance_from_last_transaction': 0.8576140872936847, 'ratio_to_median_purchase_price': 17.70614527869426, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 5.586407674186407, 'distance_from_last_transaction': 13.26107326805812, 'ratio_to_median_purchase_price': 0.0647684653704633, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.586407674186407, 'distance_from_last_transaction': 13.26107326805812, 'ratio_to_median_purchase_price': 0.0647684653704633, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.02076939528288, 'distance_from_last_transaction': 0.1780195648650336, 'ratio_to_median_purchase_price': 0.8145079406121545, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.02076939528288, 'distance_from_last_transaction': 0.1780195648650336, 'ratio_to_median_purchase_price': 0.8145079406121545, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 13.0584705141559, 'distance_from_last_transaction': 0.2560840637316123, 'ratio_to_median_purchase_price': 1.0012542942736853, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 13.0584705141559, 'distance_from_last_transaction': 0.2560840637316123, 'ratio_to_median_purchase_price': 1.0012542942736853, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.2475643282963613, 'distance_from_last_transaction': 5.60004354707232, 'ratio_to_median_purchase_price': 0.3626625780570958, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 3.922211960165817, 'distance_from_last_transaction': 4.822091480482492, 'ratio_to_median_purchase_price': 0.7037704483696168, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 3.922211960165817, 'distance_from_last_transaction': 4.822091480482492, 'ratio_to_median_purchase_price': 0.7037704483696168, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 11.67231034681138, 'distance_from_last_transaction': 0.2239037396344751, 'ratio_to_median_purchase_price': 7.443476095886652, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 11.67231034681138, 'distance_from_last_transaction': 0.2239037396344751, 'ratio_to_median_purchase_price': 7.443476095886652, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 13.445376718775696, 'distance_from_last_transaction': 0.5828560278095959, 'ratio_to_median_purchase_price': 4.868268160285668, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 13.445376718775696, 'distance_from_last_transaction': 0.5828560278095959, 'ratio_to_median_purchase_price': 4.868268160285668, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 25.51736574091718, 'distance_from_last_transaction': 0.018884654389403, 'ratio_to_median_purchase_price': 10.559113440766549, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 25.51736574091718, 'distance_from_last_transaction': 0.018884654389403, 'ratio_to_median_purchase_price': 10.559113440766549, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 1.5369209800836467, 'distance_from_last_transaction': 8.049938810132392, 'ratio_to_median_purchase_price': 13.334843665405913, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 1.5369209800836467, 'distance_from_last_transaction': 8.049938810132392, 'ratio_to_median_purchase_price': 13.334843665405913, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 67.59186117206991, 'distance_from_last_transaction': 1.6129955621122185, 'ratio_to_median_purchase_price': 0.207043004519453, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 67.59186117206991, 'distance_from_last_transaction': 1.6129955621122185, 'ratio_to_median_purchase_price': 0.207043004519453, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 335.1893199927121, 'distance_from_last_transaction': 1.1141676662234867, 'ratio_to_median_purchase_price': 0.0982428061882022, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 335.1893199927121, 'distance_from_last_transaction': 1.1141676662234867, 'ratio_to_median_purchase_price': 0.0982428061882022, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 2.131955665990563, 'distance_from_last_transaction': 56.3724005365082, 'ratio_to_median_purchase_price': 6.358667321630612, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.131955665990563, 'distance_from_last_transaction': 56.3724005365082, 'ratio_to_median_purchase_price': 6.358667321630612, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 111.28520610936934, 'distance_from_last_transaction': 0.3790316875990881, 'ratio_to_median_purchase_price': 1.8584721733251552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 111.28520610936934, 'distance_from_last_transaction': 0.3790316875990881, 'ratio_to_median_purchase_price': 1.8584721733251552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 24.33748770584292, 'distance_from_last_transaction': 1.3986182664381062, 'ratio_to_median_purchase_price': 6.230792396550816, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 24.33748770584292, 'distance_from_last_transaction': 1.3986182664381062, 'ratio_to_median_purchase_price': 6.230792396550816, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 17.043384432449976, 'distance_from_last_transaction': 0.3282733826369984, 'ratio_to_median_purchase_price': 0.3472038763553988, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 17.043384432449976, 'distance_from_last_transaction': 0.3282733826369984, 'ratio_to_median_purchase_price': 0.3472038763553988, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 10.594372771059918, 'distance_from_last_transaction': 0.300184221962306, 'ratio_to_median_purchase_price': 4.766703962782415, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 10.594372771059918, 'distance_from_last_transaction': 0.300184221962306, 'ratio_to_median_purchase_price': 4.766703962782415, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 15.23536145541202, 'distance_from_last_transaction': 0.300208724552423, 'ratio_to_median_purchase_price': 0.4642727680509552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 15.23536145541202, 'distance_from_last_transaction': 0.300208724552423, 'ratio_to_median_purchase_price': 0.4642727680509552, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 10.664473716016785, 'distance_from_last_transaction': 1.565769086201661, 'ratio_to_median_purchase_price': 4.886520843107555, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 10.664473716016785, 'distance_from_last_transaction': 1.565769086201661, 'ratio_to_median_purchase_price': 4.886520843107555, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 3.2160447557707816, 'distance_from_last_transaction': 17.144735923073647, 'ratio_to_median_purchase_price': 1.788833243120637, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 3.2160447557707816, 'distance_from_last_transaction': 17.144735923073647, 'ratio_to_median_purchase_price': 1.788833243120637, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 85.83725334092371, 'distance_from_last_transaction': 1.0351178763066122, 'ratio_to_median_purchase_price': 0.8682956142370105, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 85.83725334092371, 'distance_from_last_transaction': 1.0351178763066122, 'ratio_to_median_purchase_price': 0.8682956142370105, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 1.1158806875176952, 'distance_from_last_transaction': 0.1702369279899755, 'ratio_to_median_purchase_price': 4.127313378541158, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 1.1158806875176952, 'distance_from_last_transaction': 0.1702369279899755, 'ratio_to_median_purchase_price': 4.127313378541158, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 12.750894983835098, 'distance_from_last_transaction': 0.8576140872936847, 'ratio_to_median_purchase_price': 17.70614527869426, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 12.750894983835098, 'distance_from_last_transaction': 0.8576140872936847, 'ratio_to_median_purchase_price': 17.70614527869426, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 5.586407674186407, 'distance_from_last_transaction': 13.26107326805812, 'ratio_to_median_purchase_price': 0.0647684653704633, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.586407674186407, 'distance_from_last_transaction': 13.26107326805812, 'ratio_to_median_purchase_price': 0.0647684653704633, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.02076939528288, 'distance_from_last_transaction': 0.1780195648650336, 'ratio_to_median_purchase_price': 0.8145079406121545, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.02076939528288, 'distance_from_last_transaction': 0.1780195648650336, 'ratio_to_median_purchase_price': 0.8145079406121545, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 5.764412015004839, 'distance_from_last_transaction': 0.624542382351953, 'ratio_to_median_purchase_price': 8.56593477975357, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.764412015004839, 'distance_from_last_transaction': 0.624542382351953, 'ratio_to_median_purchase_price': 8.56593477975357, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 181.86331424612112, 'distance_from_last_transaction': 0.4847605839040534, 'ratio_to_median_purchase_price': 1.9557071972465696, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 181.86331424612112, 'distance_from_last_transaction': 0.4847605839040534, 'ratio_to_median_purchase_price': 1.9557071972465696, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 78.62324228597946, 'distance_from_last_transaction': 1.409245200233365, 'ratio_to_median_purchase_price': 1.8380164275927835, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 78.62324228597946, 'distance_from_last_transaction': 1.409245200233365, 'ratio_to_median_purchase_price': 1.8380164275927835, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 88.15891899379177, 'distance_from_last_transaction': 0.6552597799376982, 'ratio_to_median_purchase_price': 5.433499527157334, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 88.15891899379177, 'distance_from_last_transaction': 0.6552597799376982, 'ratio_to_median_purchase_price': 5.433499527157334, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 19.613741461684786, 'distance_from_last_transaction': 4.394683062780756, 'ratio_to_median_purchase_price': 4.937606527090611, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 19.613741461684786, 'distance_from_last_transaction': 4.394683062780756, 'ratio_to_median_purchase_price': 4.937606527090611, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 18.22039233506801, 'distance_from_last_transaction': 6.885983628531424, 'ratio_to_median_purchase_price': 0.302610408525304, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 18.22039233506801, 'distance_from_last_transaction': 6.885983628531424, 'ratio_to_median_purchase_price': 0.302610408525304, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 22.545587575167414, 'distance_from_last_transaction': 0.3539392546618495, 'ratio_to_median_purchase_price': 4.095442206076704, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 22.545587575167414, 'distance_from_last_transaction': 0.3539392546618495, 'ratio_to_median_purchase_price': 4.095442206076704, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 8.084177482766684, 'distance_from_last_transaction': 0.1382028064237024, 'ratio_to_median_purchase_price': 0.3786612352998621, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 1.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 8.084177482766684, 'distance_from_last_transaction': 0.1382028064237024, 'ratio_to_median_purchase_price': 0.3786612352998621, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 1.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 43.32644363556807, 'distance_from_last_transaction': 0.2052546161410341, 'ratio_to_median_purchase_price': 4.250634052124063, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 43.32644363556807, 'distance_from_last_transaction': 0.2052546161410341, 'ratio_to_median_purchase_price': 4.250634052124063, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 537.1514655092042, 'distance_from_last_transaction': 1.639335482331624, 'ratio_to_median_purchase_price': 1.8994623698524835, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 537.1514655092042, 'distance_from_last_transaction': 1.639335482331624, 'ratio_to_median_purchase_price': 1.8994623698524835, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 31.892352665494183, 'distance_from_last_transaction': 0.1203523607154728, 'ratio_to_median_purchase_price': 0.3485856336471177, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 31.892352665494183, 'distance_from_last_transaction': 0.1203523607154728, 'ratio_to_median_purchase_price': 0.3485856336471177, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 112.08715586311428, 'distance_from_last_transaction': 0.2980125709938463, 'ratio_to_median_purchase_price': 2.339287241235982, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 112.08715586311428, 'distance_from_last_transaction': 0.2980125709938463, 'ratio_to_median_purchase_price': 2.339287241235982, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 15.693303060946976, 'distance_from_last_transaction': 4.177117000371978, 'ratio_to_median_purchase_price': 0.3313219539992365, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 15.693303060946976, 'distance_from_last_transaction': 4.177117000371978, 'ratio_to_median_purchase_price': 0.3313219539992365, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.530145018135443, 'distance_from_last_transaction': 3.6897810904940105, 'ratio_to_median_purchase_price': 8.297406866219774, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.530145018135443, 'distance_from_last_transaction': 3.6897810904940105, 'ratio_to_median_purchase_price': 8.297406866219774, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 3.5896485976213444, 'distance_from_last_transaction': 6.247457541963805, 'ratio_to_median_purchase_price': 1.8464505265933648, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 3.5896485976213444, 'distance_from_last_transaction': 6.247457541963805, 'ratio_to_median_purchase_price': 1.8464505265933648, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 114.51978939161216, 'distance_from_last_transaction': 0.7070032526577117, 'ratio_to_median_purchase_price': 0.516989925221995, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 114.51978939161216, 'distance_from_last_transaction': 0.7070032526577117, 'ratio_to_median_purchase_price': 0.516989925221995, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 965.9106119620062, 'distance_from_last_transaction': 0.0236040085750649, 'ratio_to_median_purchase_price': 0.2579081017144914, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 965.9106119620062, 'distance_from_last_transaction': 0.0236040085750649, 'ratio_to_median_purchase_price': 0.2579081017144914, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 1.3795527755550008, 'distance_from_last_transaction': 0.0564859884060373, 'ratio_to_median_purchase_price': 4.871942856500879, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 1.3795527755550008, 'distance_from_last_transaction': 0.0564859884060373, 'ratio_to_median_purchase_price': 4.871942856500879, 'repeat_retailer': 0.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 13.391376161720784, 'distance_from_last_transaction': 0.4066453559110527, 'ratio_to_median_purchase_price': 5.711177073871606, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 13.391376161720784, 'distance_from_last_transaction': 0.4066453559110527, 'ratio_to_median_purchase_price': 5.711177073871606, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 386.0952542627018, 'distance_from_last_transaction': 5.367957485452141, 'ratio_to_median_purchase_price': 1.6157354230697163, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 386.0952542627018, 'distance_from_last_transaction': 5.367957485452141, 'ratio_to_median_purchase_price': 1.6157354230697163, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 151.37043724281128, 'distance_from_last_transaction': 5.340080994904885, 'ratio_to_median_purchase_price': 1.171566647935164, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 151.37043724281128, 'distance_from_last_transaction': 5.340080994904885, 'ratio_to_median_purchase_price': 1.171566647935164, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 7.847434936666215, 'distance_from_last_transaction': 0.6712826918709495, 'ratio_to_median_purchase_price': 1.0705985323463172, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 7.847434936666215, 'distance_from_last_transaction': 0.6712826918709495, 'ratio_to_median_purchase_price': 1.0705985323463172, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 7.230067263034045, 'distance_from_last_transaction': 4.029308624131385, 'ratio_to_median_purchase_price': 5.746112420698082, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 7.230067263034045, 'distance_from_last_transaction': 4.029308624131385, 'ratio_to_median_purchase_price': 5.746112420698082, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 34.41390100453567, 'distance_from_last_transaction': 25.29759752778163, 'ratio_to_median_purchase_price': 14.697713119893285, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 34.41390100453567, 'distance_from_last_transaction': 25.29759752778163, 'ratio_to_median_purchase_price': 14.697713119893285, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 4.426862415904887, 'distance_from_last_transaction': 5.144466643610322, 'ratio_to_median_purchase_price': 2.323604269260222, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 4.426862415904887, 'distance_from_last_transaction': 5.144466643610322, 'ratio_to_median_purchase_price': 2.323604269260222, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 37.09366042581375, 'distance_from_last_transaction': 10.231150752374784, 'ratio_to_median_purchase_price': 5.776353953919113, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 37.09366042581375, 'distance_from_last_transaction': 10.231150752374784, 'ratio_to_median_purchase_price': 5.776353953919113, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 765.2825592612469, 'distance_from_last_transaction': 0.3715619621963146, 'ratio_to_median_purchase_price': 0.5512447476281009, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 765.2825592612469, 'distance_from_last_transaction': 0.3715619621963146, 'ratio_to_median_purchase_price': 0.5512447476281009, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 5.7938900041198025, 'distance_from_last_transaction': 2.758511012799268, 'ratio_to_median_purchase_price': 5.085685575610163, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.7938900041198025, 'distance_from_last_transaction': 2.758511012799268, 'ratio_to_median_purchase_price': 5.085685575610163, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 601.5229191365606, 'distance_from_last_transaction': 0.0287232060087352, 'ratio_to_median_purchase_price': 0.8597786295284634, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 601.5229191365606, 'distance_from_last_transaction': 0.0287232060087352, 'ratio_to_median_purchase_price': 0.8597786295284634, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 26.711462023719893, 'distance_from_last_transaction': 1.5520081259491354, 'ratio_to_median_purchase_price': 4.603600688206188, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 26.711462023719893, 'distance_from_last_transaction': 1.5520081259491354, 'ratio_to_median_purchase_price': 4.603600688206188, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# ...
# 📥 Transação recebida: {'distance_from_home': 25.18027797998742, 'distance_from_last_transaction': 1.790907339297758, 'ratio_to_median_purchase_price': 4.595736199636936, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 25.18027797998742, 'distance_from_last_transaction': 1.790907339297758, 'ratio_to_median_purchase_price': 4.595736199636936, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 2.148084810674618, 'distance_from_last_transaction': 0.4163982038248041, 'ratio_to_median_purchase_price': 1.0374280646992489, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 1.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.148084810674618, 'distance_from_last_transaction': 0.4163982038248041, 'ratio_to_median_purchase_price': 1.0374280646992489, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 1.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 4.848246572280567, 'distance_from_last_transaction': 0.3207354272228163, 'ratio_to_median_purchase_price': 1.2730495235601782, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 1.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 4.848246572280567, 'distance_from_last_transaction': 0.3207354272228163, 'ratio_to_median_purchase_price': 1.2730495235601782, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 1.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 53.46555834293632, 'distance_from_last_transaction': 0.0884066254666023, 'ratio_to_median_purchase_price': 0.2046127015143529, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 53.46555834293632, 'distance_from_last_transaction': 0.0884066254666023, 'ratio_to_median_purchase_price': 0.2046127015143529, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 13.113595913622362, 'distance_from_last_transaction': 0.3889088942634553, 'ratio_to_median_purchase_price': 4.4091602261932135, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 13.113595913622362, 'distance_from_last_transaction': 0.3889088942634553, 'ratio_to_median_purchase_price': 4.4091602261932135, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 43.28131438308468, 'distance_from_last_transaction': 3.3677926241961704, 'ratio_to_median_purchase_price': 0.6760582745829428, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 1.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 43.28131438308468, 'distance_from_last_transaction': 3.3677926241961704, 'ratio_to_median_purchase_price': 0.6760582745829428, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 1.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 8.83904670372637, 'distance_from_last_transaction': 2.9705122760243827, 'ratio_to_median_purchase_price': 2.36168254706846, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 8.83904670372637, 'distance_from_last_transaction': 2.9705122760243827, 'ratio_to_median_purchase_price': 2.36168254706846, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 13.95597236704443, 'distance_from_last_transaction': 0.2715215283485692, 'ratio_to_median_purchase_price': 2.798901124938246, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 13.95597236704443, 'distance_from_last_transaction': 0.2715215283485692, 'ratio_to_median_purchase_price': 2.798901124938246, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 83.19190905345448, 'distance_from_last_transaction': 0.974245099181972, 'ratio_to_median_purchase_price': 2.204589077385998, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 83.19190905345448, 'distance_from_last_transaction': 0.974245099181972, 'ratio_to_median_purchase_price': 2.204589077385998, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 2.493433495597399, 'distance_from_last_transaction': 0.7794254269297773, 'ratio_to_median_purchase_price': 4.007341140404431, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 2.493433495597399, 'distance_from_last_transaction': 0.7794254269297773, 'ratio_to_median_purchase_price': 4.007341140404431, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 170.24705804991328, 'distance_from_last_transaction': 0.4191106592020203, 'ratio_to_median_purchase_price': 0.153334337580427, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 170.24705804991328, 'distance_from_last_transaction': 0.4191106592020203, 'ratio_to_median_purchase_price': 0.153334337580427, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 3.8030573513256014, 'distance_from_last_transaction': 67.24108052618409, 'ratio_to_median_purchase_price': 1.872949614304464, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 3.8030573513256014, 'distance_from_last_transaction': 67.24108052618409, 'ratio_to_median_purchase_price': 1.872949614304464, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 5.091079490616996, 'distance_from_last_transaction': 0.8051525945853258, 'ratio_to_median_purchase_price': 0.4277145611942758, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.091079490616996, 'distance_from_last_transaction': 0.8051525945853258, 'ratio_to_median_purchase_price': 0.4277145611942758, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 7.3354844398713315, 'distance_from_last_transaction': 0.3448675931869471, 'ratio_to_median_purchase_price': 15.511619585551465, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 7.3354844398713315, 'distance_from_last_transaction': 0.3448675931869471, 'ratio_to_median_purchase_price': 15.511619585551465, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 15.694985541059944, 'distance_from_last_transaction': 175.98918151972342, 'ratio_to_median_purchase_price': 0.8556228290724207, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 15.694985541059944, 'distance_from_last_transaction': 175.98918151972342, 'ratio_to_median_purchase_price': 0.8556228290724207, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 7.888322856357224, 'distance_from_last_transaction': 0.5130490425957464, 'ratio_to_median_purchase_price': 5.337625815459592, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 7.888322856357224, 'distance_from_last_transaction': 0.5130490425957464, 'ratio_to_median_purchase_price': 5.337625815459592, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'fraude'}
# 📥 Transação recebida: {'distance_from_home': 14.12790501001848, 'distance_from_last_transaction': 5.862020928481165, 'ratio_to_median_purchase_price': 0.2927730476968923, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 14.12790501001848, 'distance_from_last_transaction': 5.862020928481165, 'ratio_to_median_purchase_price': 0.2927730476968923, 'repeat_retailer': 1.0, 'used_chip': 1.0, 'used_pin_number': 0.0, 'online_order': 1.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 5.471113979085435, 'distance_from_last_transaction': 1.0241780871042283, 'ratio_to_median_purchase_price': 0.0671805015773473, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.471113979085435, 'distance_from_last_transaction': 1.0241780871042283, 'ratio_to_median_purchase_price': 0.0671805015773473, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# 📥 Transação recebida: {'distance_from_home': 5.482982321943006, 'distance_from_last_transaction': 3.501975947166019, 'ratio_to_median_purchase_price': 1.9864672540042143, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0}
# 📤 Transação enviada para o Elasticsearch: {'distance_from_home': 5.482982321943006, 'distance_from_last_transaction': 3.501975947166019, 'ratio_to_median_purchase_price': 1.9864672540042143, 'repeat_retailer': 1.0, 'used_chip': 0.0, 'used_pin_number': 0.0, 'online_order': 0.0, 'resultado_previsao': 'aprovada'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 24
#      20 modelo = joblib.load(r"C:\Users\Matheus\Desktop\Estudo\Kafka\Transação_Credito\Previsao\models\fraud_detection.pkl")
#      22 print("🚀 Aguardando transações...")
# ---> 24 for msg in consumer:
#      25     try:
#      26         # Ler mensagem do Kafka
#      27         data = json.loads(msg.value.decode('utf-8'))  # Decodificar bytes para string e carregar como JSON
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:
